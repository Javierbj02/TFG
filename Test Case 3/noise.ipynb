# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/No ruido/ULA_8.csv")

# %%
def add_noise(data, percentage):
    """
    Adds Gaussian noise to the dataset with specified noise level.
    
    Args:
    - data (DataFrame): Original dataset without noise.
    - num (float): Noise level factor to multiply with standard deviation.
    
    Returns:
    - DataFrame: Dataset with added noise.
    """
    
    posicionX = data['PosicionX']
    posicionY = data['PosicionY']

    # Elimino las columnas de posición
    data = data.drop(['PosicionX', 'PosicionY'], axis=1)

    columns_modulo = data.columns[::2]  # Columnas de los módulos
    columns_fase = data.columns[1::2]  # Columnas de las fases

    range_modulus = 1.0
    range_phase = 2 * np.pi

    std_devs_modulo = percentage * range_modulus
    std_devs_fase = percentage * range_phase

    # Generar ruido gaussiano para los módulos
    noise_modulo = np.random.normal(loc=0, scale=std_devs_modulo, size=data[columns_modulo].shape)
    # Generar ruido gaussiano para las fases
    noise_fase = np.random.normal(loc=0, scale=std_devs_fase, size=data[columns_fase].shape)

    data_noisy = data.copy()
    data_noisy[columns_modulo] += noise_modulo
    data_noisy[columns_fase] += noise_fase

    # Acotar los valores
    data_noisy[columns_modulo] = np.clip(data_noisy[columns_modulo], 0, 1)
    data_noisy[columns_fase] = np.clip(data_noisy[columns_fase], -np.pi, np.pi)

    # Añadir de nuevo las posiciones
    data_noisy['PosicionX'] = posicionX
    data_noisy['PosicionY'] = posicionY

    return data_noisy

# Ejemplo de uso:
data = df.copy()
noisy_data_low = add_noise(data, 0.10)
noisy_data_mid = add_noise(data, 0.20)
noisy_data_high = add_noise(data, 0.30)

noisy_data_low.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido bajo/ULA_8.csv", index=False)
noisy_data_mid.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido medio/ULA_8.csv", index=False)
noisy_data_high.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido elevado/ULA_8.csv", index=False)
# Out:
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\3178821447.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionX'] = posicionX
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\3178821447.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionY'] = posicionY
# ...

# %%
df = pd.read_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/No ruido/ULA_16.csv")

# %%
def add_noise(data, percentage):
    """
    Adds Gaussian noise to the dataset with specified noise level.
    
    Args:
    - data (DataFrame): Original dataset without noise.
    - num (float): Noise level factor to multiply with standard deviation.
    
    Returns:
    - DataFrame: Dataset with added noise.
    """
    
    posicionX = data['PosicionX']
    posicionY = data['PosicionY']

    # Elimino las columnas de posición
    data = data.drop(['PosicionX', 'PosicionY'], axis=1)

    columns_modulo = data.columns[::2]  # Columnas de los módulos
    columns_fase = data.columns[1::2]  # Columnas de las fases

    range_modulus = 1.0
    range_phase = 2 * np.pi

    std_devs_modulo = percentage * range_modulus
    std_devs_fase = percentage * range_phase

    # Generar ruido gaussiano para los módulos
    noise_modulo = np.random.normal(loc=0, scale=std_devs_modulo, size=data[columns_modulo].shape)
    # Generar ruido gaussiano para las fases
    noise_fase = np.random.normal(loc=0, scale=std_devs_fase, size=data[columns_fase].shape)

    data_noisy = data.copy()
    data_noisy[columns_modulo] += noise_modulo
    data_noisy[columns_fase] += noise_fase

    # Acotar los valores
    data_noisy[columns_modulo] = np.clip(data_noisy[columns_modulo], 0, 1)
    data_noisy[columns_fase] = np.clip(data_noisy[columns_fase], -np.pi, np.pi)

    # Añadir de nuevo las posiciones
    data_noisy['PosicionX'] = posicionX
    data_noisy['PosicionY'] = posicionY

    return data_noisy

# Ejemplo de uso:
data = df.copy()
noisy_data_low = add_noise(data, 0.10)
noisy_data_mid = add_noise(data, 0.20)
noisy_data_high = add_noise(data, 0.30)

noisy_data_low.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido bajo/ULA_16.csv", index=False)
noisy_data_mid.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido medio/ULA_16.csv", index=False)
noisy_data_high.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido elevado/ULA_16.csv", index=False)
# Out:
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\60046716.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionX'] = posicionX
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\60046716.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionY'] = posicionY
# ...

# %%
df = pd.read_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/No ruido/ULA_32.csv")

# %%
def add_noise(data, percentage):
    """
    Adds Gaussian noise to the dataset with specified noise level.
    
    Args:
    - data (DataFrame): Original dataset without noise.
    - num (float): Noise level factor to multiply with standard deviation.
    
    Returns:
    - DataFrame: Dataset with added noise.
    """
    
    posicionX = data['PosicionX']
    posicionY = data['PosicionY']

    # Elimino las columnas de posición
    data = data.drop(['PosicionX', 'PosicionY'], axis=1)

    columns_modulo = data.columns[::2]  # Columnas de los módulos
    columns_fase = data.columns[1::2]  # Columnas de las fases

    range_modulus = 1.0
    range_phase = 2 * np.pi

    std_devs_modulo = percentage * range_modulus
    std_devs_fase = percentage * range_phase

    # Generar ruido gaussiano para los módulos
    noise_modulo = np.random.normal(loc=0, scale=std_devs_modulo, size=data[columns_modulo].shape)
    # Generar ruido gaussiano para las fases
    noise_fase = np.random.normal(loc=0, scale=std_devs_fase, size=data[columns_fase].shape)

    data_noisy = data.copy()
    data_noisy[columns_modulo] += noise_modulo
    data_noisy[columns_fase] += noise_fase

    # Acotar los valores
    data_noisy[columns_modulo] = np.clip(data_noisy[columns_modulo], 0, 1)
    data_noisy[columns_fase] = np.clip(data_noisy[columns_fase], -np.pi, np.pi)

    # Añadir de nuevo las posiciones
    data_noisy['PosicionX'] = posicionX
    data_noisy['PosicionY'] = posicionY

    return data_noisy

# Ejemplo de uso:
data = df.copy()
noisy_data_low = add_noise(data, 0.10)
noisy_data_mid = add_noise(data, 0.20)
noisy_data_high = add_noise(data, 0.30)

noisy_data_low.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido bajo/ULA_32.csv", index=False)
noisy_data_mid.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido medio/ULA_32.csv", index=False)
noisy_data_high.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido elevado/ULA_32.csv", index=False)
# Out:
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\1640114543.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionX'] = posicionX
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\1640114543.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionY'] = posicionY
# ...

# %%
df = pd.read_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/No ruido/ULA_64.csv")

# %%
def add_noise(data, percentage):
    """
    Adds Gaussian noise to the dataset with specified noise level.
    
    Args:
    - data (DataFrame): Original dataset without noise.
    - num (float): Noise level factor to multiply with standard deviation.
    
    Returns:
    - DataFrame: Dataset with added noise.
    """
    
    posicionX = data['PosicionX']
    posicionY = data['PosicionY']

    # Elimino las columnas de posición
    data = data.drop(['PosicionX', 'PosicionY'], axis=1)

    columns_modulo = data.columns[::2]  # Columnas de los módulos
    columns_fase = data.columns[1::2]  # Columnas de las fases

    range_modulus = 1.0
    range_phase = 2 * np.pi

    std_devs_modulo = percentage * range_modulus
    std_devs_fase = percentage * range_phase

    # Generar ruido gaussiano para los módulos
    noise_modulo = np.random.normal(loc=0, scale=std_devs_modulo, size=data[columns_modulo].shape)
    # Generar ruido gaussiano para las fases
    noise_fase = np.random.normal(loc=0, scale=std_devs_fase, size=data[columns_fase].shape)

    data_noisy = data.copy()
    data_noisy[columns_modulo] += noise_modulo
    data_noisy[columns_fase] += noise_fase

    # Acotar los valores
    data_noisy[columns_modulo] = np.clip(data_noisy[columns_modulo], 0, 1)
    data_noisy[columns_fase] = np.clip(data_noisy[columns_fase], -np.pi, np.pi)

    # Añadir de nuevo las posiciones
    data_noisy['PosicionX'] = posicionX
    data_noisy['PosicionY'] = posicionY

    return data_noisy

# Ejemplo de uso:
data = df.copy()
noisy_data_low = add_noise(data, 0.10)
noisy_data_mid = add_noise(data, 0.20)
noisy_data_high = add_noise(data, 0.30)

noisy_data_low.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido bajo/ULA_64.csv", index=False)
noisy_data_mid.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido medio/ULA_64.csv", index=False)
noisy_data_high.to_csv("C:/Users/javi2/Desktop/TFG - Webots/TFG/Data/Test Case 3/Ruido elevado/ULA_64.csv", index=False)
# Out:
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\1456783126.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionX'] = posicionX
# C:\Users\javi2\AppData\Local\Temp\ipykernel_27560\1456783126.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_noisy['PosicionY'] = posicionY
# ...
